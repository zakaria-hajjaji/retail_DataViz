# %%
import pandas as  pd 
import numpy as np 
import matplotlib as plt

# %%
df=pd.read_excel("/content/Copie de data_fusionnée_(860).xls")
# Out:
# /usr/local/lib/python3.7/dist-packages/xlrd/book.py:74: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   t0 = time.clock()

# %%
df.head()
# Out:
#          city                      type Sous_type  ...  Gender      Membre Age
# 0  Casablanca  Alimentation et boissons       Eau  ...   femme  non membre  49
# 1       Rabat  Alimentation et boissons       Eau  ...   femme  non membre  28
# 2       Rabat  Alimentation et boissons       Eau  ...   femme  non membre  40
# 3       Rabat  Alimentation et boissons       Eau  ...   femme  non membre  40
# 4       Rabat  Alimentation et boissons       Eau  ...   femme  non membre  32
#
# [5 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        2000 non-null   object
#  1   type        2000 non-null   object
#  2   Sous_type   2000 non-null   object
#  3   unit_price  2000 non-null   float64
#  4   quantity    2000 non-null   int64
#  5   date        2000 non-null   object
#  6   time        2000 non-null   object
#  7   payment     2000 non-null   object
#  8   cost        2000 non-null   float64
#  9   rating      2000 non-null   float64
#  10  ID_Client   2000 non-null   int64
#  11  Gender      2000 non-null   object
#  12  Membre      2000 non-null   object
#  13  Age         2000 non-null   int64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 218.9+ KB

# %%
df.shape
# Out:
# (2000, 14)

# %%
df.isnull().sum()
# Out:
# city          0
# type          0
# Sous_type     0
# unit_price    0
# quantity      0
# date          0
# time          0
# payment       0
# cost          0
# rating        0
# ID_Client     0
# Gender        0
# Membre        0
# Age           0
# dtype: int64

# %%
df.hist(figsize=(12,9))
plt.pyplot.show()

# %%
df["payment"].value_counts().plot(kind='barh')

# %%
df["type"].value_counts().plot(kind='barh')

plt.pyplot.xlabel('Frequency')
# Out:
# Text(0.5, 0, 'Frequency')

# %%
df['city'].value_counts().plot(kind='bar')

# %%
df.describe()
# Out:
#         unit_price     quantity  ...     ID_Client          Age
# count  2000.000000  2000.000000  ...  2.000000e+03  2000.000000
# mean     53.392065     4.784500  ...  1.878128e+08    33.860000
# std      27.816614     2.617725  ...  4.713534e+07     8.111923
# min       1.000000     1.000000  ...  1.011762e+08    20.000000
# 25%      30.000000     3.000000  ...  1.487214e+08    28.000000
# 50%      53.255000     5.000000  ...  1.892897e+08    34.000000
# 75%      77.080000     7.000000  ...  2.297493e+08    40.000000
# max     100.000000    10.000000  ...  2.680362e+08    49.000000
#
# [8 rows x 6 columns]

# %%
df.corr()
# Out:
#             unit_price  quantity      cost    rating  ID_Client       Age
# unit_price    1.000000  0.030686  0.644837  0.070897   0.003391  0.006414
# quantity      0.030686  1.000000  0.700170  0.224277   0.018367  0.047037
# cost          0.644837  0.700170  1.000000  0.189532   0.023553  0.046099
# rating        0.070897  0.224277  0.189532  1.000000   0.002545 -0.005749
# ID_Client     0.003391  0.018367  0.023553  0.002545   1.000000  0.020127
# Age           0.006414  0.047037  0.046099 -0.005749   0.020127  1.000000

# %%
import seaborn as sns
sns.catplot(x="Gender", kind="count", palette="ch:.25",data=df)

# %%
sns.swarmplot(x="type",  y = "rating",  hue = "city", data =df).set_title("type des clients par ville")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 51.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 21.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 18.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 48.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.catplot(x='type',y='unit_price',hue='city',data=df,aspect=2,jitter=False)

# %%
plt.pyplot.figure(dpi=125) 
sns.distplot(df['rating'],kde=False)
plt.pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.catplot(y ='rating',x='type', data = df,kind='boxen',aspect=3) 
plt.pyplot.xlabel('type')
plt.pyplot.ylabel('Rating')
plt.pyplot.show()

# %%
sns.heatmap(df.corr(),annot=True)

# %%
df.ID_Client.value_counts()
# Out:
# 211050490    10
# 136086195    10
# 257731380    10
# 139522867    10
# 196012849    10
#              ..
# 186438965    10
# 149716266    10
# 126541082    10
# 169524504    10
# 125452293    10
# Name: ID_Client, Length: 200, dtype: int64

# %%
sel_uniID=df[df.ID_Client == 175542529]
sel_uniID.head(10)
# Out:
#             city                       type  ...  Membre  Age
# 8         Tanger   Alimentation et boissons  ...  membre   29
# 490       Tanger  Accessoires electroniques  ...  membre   29
# 565        Rabat       Maison et decoration  ...  membre   29
# 701       Tanger            Santé et Beauté  ...  membre   29
# 735   Casablanca            Santé et Beauté  ...  membre   29
# 1031  Casablanca                   Fashions  ...  membre   29
# 1221  Casablanca                   Fashions  ...  membre   29
# 1522  Casablanca   Alimentation et boissons  ...  membre   29
# 1682  Casablanca       Maison et decoration  ...  membre   29
# 1862  Casablanca            Sport et Voyage  ...  membre   29
#
# [10 rows x 14 columns]

# %%
sel_uniID.type.value_counts().plot(kind='barh')

# %%
ratings = pd.DataFrame(sel_uniID.groupby('type')['rating'])

ratings.head()
# Out:
#                            0                                                  1
# 0  Accessoires electroniques            490    7.6
# Name: rating, dtype: float64
# 1   Alimentation et boissons  8       7.4
# 1522    2.0
# Name: rating, dtype: f...
# 2                   Fashions  1031    3.0
# 1221    1.0
# Name: rating, dtype: f...
# 3       Maison et decoration  565     4.2
# 1682    3.0
# Name: rating, dtype: f...
# 4            Santé et Beauté  701    8.9
# 735    7.5
# Name: rating, dtype: flo...

# %%
tend_sexef=df[df.Gender == 'femme']
tend_sexeh=df[df.Gender == 'homme']

# %%
tend_sexeh.head(8)
# Out:
#           city                      type Sous_type  ...  Gender  Membre Age
# 5        Rabat  Alimentation et boissons       Eau  ...   homme  membre  36
# 6   Casablanca  Alimentation et boissons       Eau  ...   homme  membre  36
# 7       Tanger  Alimentation et boissons       Eau  ...   homme  membre  34
# 8       Tanger  Alimentation et boissons       Eau  ...   homme  membre  29
# 9        Rabat  Alimentation et boissons       Eau  ...   homme  membre  22
# 10  Casablanca  Alimentation et boissons       Eau  ...   homme  membre  31
# 14  Casablanca  Alimentation et boissons       Eau  ...   homme  membre  47
# 18  Casablanca  Alimentation et boissons       Eau  ...   homme  membre  29
#
# [8 rows x 14 columns]

# %%
tend_sexeh.describe()
# Out:
#         unit_price    quantity  ...     ID_Client          Age
# count  1000.000000  1000.00000  ...  1.000000e+03  1000.000000
# mean     53.074830     4.81200  ...  1.875698e+08    33.648000
# std      27.984474     2.63203  ...  4.724382e+07     8.115661
# min       1.000000     1.00000  ...  1.011762e+08    20.000000
# 25%      28.755000     3.00000  ...  1.488225e+08    28.000000
# 50%      53.000000     5.00000  ...  1.894052e+08    33.000000
# 75%      76.840000     7.00000  ...  2.321130e+08    40.000000
# max     100.000000    10.00000  ...  2.680362e+08    49.000000
#
# [8 rows x 6 columns]

# %%
tend_sexef.describe()
# Out:
#         unit_price     quantity  ...     ID_Client          Age
# count  1000.000000  1000.000000  ...  1.000000e+03  1000.000000
# mean     53.709300     4.757000  ...  1.880558e+08    34.072000
# std      27.658096     2.604368  ...  4.704899e+07     8.106697
# min       1.000000     1.000000  ...  1.011762e+08    20.000000
# 25%      31.000000     3.000000  ...  1.484179e+08    28.000000
# 50%      54.035000     5.000000  ...  1.891742e+08    35.000000
# 75%      77.690000     7.000000  ...  2.289614e+08    40.000000
# max     100.000000    10.000000  ...  2.680362e+08    49.000000
#
# [8 rows x 6 columns]

# %%
df['time'] = pd.to_datetime(df['time'])

# %%
df['time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
tend_sexeh.type.value_counts().plot(kind='barh')

# %%
tend_sexef.type.value_counts().plot(kind='barh')

# %%
sns.catplot(y ='rating',x='type', data = tend_sexeh,kind='boxen',aspect=3) 
plt.pyplot.xlabel('type')
plt.pyplot.ylabel('Rating')
plt.pyplot.show()

# %%
df['time'].value_counts()
# Out:
# 2021-10-07 19:48:00    14
# 2021-10-07 14:42:00    14
# 2021-10-07 17:38:00    12
# 2021-10-07 11:51:00    10
# 2021-10-07 13:48:00    10
#                        ..
# 2021-10-07 10:30:00     2
# 2021-10-07 15:25:00     2
# 2021-10-07 10:34:00     2
# 2021-10-07 15:32:00     2
# 2021-10-07 10:19:00     2
# Name: time, Length: 506, dtype: int64

# %%
df['Hour'] = (df['time']).dt.hour

# %%
genderCount  = sns.lineplot(x="Hour",  y = 'quantity',data =df).set_title("Product vendues par heure")

# %%
df['Age'].unique()
# Out:
# array([49, 28, 40, 32, 36, 34, 29, 22, 31, 38, 47, 37, 42, 35, 33, 20, 24,
#        45, 27, 48, 26, 39, 43, 23, 41, 30, 25, 21, 44, 46])
